# %% [markdown]
# Import the Libraries and Load the Dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Step 1: Load the Iris dataset
iris = datasets.load_iris()
X = iris.data  # Features (sepal length, sepal width, petal length, petal width)
y = iris.target  # Target labels (species)

# %% [markdown]
# Standardize the data (optional, but often improves performance for PCA)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Apply PCA (Principal Component Analysis) to reduce dimensions to 2

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# Create a DataFrame for the PCA results (for visualization)

# %%
import pandas as pd
df_pca = pd.DataFrame(data=X_pca, columns=['PCA1', 'PCA2'])
df_pca['Species'] = iris.target_names[y]  # Add the target species labels

# %% [markdown]
# Plot the 2D PCA plot

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PCA1', y='PCA2', hue='Species', data=df_pca, palette='Set1', s=100, edgecolor='black', marker='o')
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>

# %% [markdown]
# Customize the plot

# %%
plt.title('2D PCA of Iris Dataset', fontsize=16)
plt.xlabel('Principal Component 1', fontsize=12)
plt.ylabel('Principal Component 2', fontsize=12)
plt.legend(title='Species')
plt.grid(True)

# Show the plot
plt.show()
# Out:
# <ipython-input-6-47001dc2636c>:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Species')
